# %% [markdown]
# # 초음파 광물 예측 데이터
#
# - 1988년 존스홉킨스대학교의 세즈노프스키 교수가 1986 힌튼교수(딥러닝 만드신분)가 발표한 역전파 알고리즘에 관심을 갖고 은닉층과 역전파의 효과를 실험하기 위해 정리한 데이터
# - 광석과 일반 돌에 각각 음파 탐지기를 쏜 후 그 결과를 정리

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential, load_model
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('./data/sonar.csv', header=None)

# %%
df.head()
# Out:
#        0       1       2       3       4       5       6   ...      54      55      56      57      58      59  60
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  ...  0.0072  0.0167  0.0180  0.0084  0.0090  0.0032   R
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  ...  0.0094  0.0191  0.0140  0.0049  0.0052  0.0044   R
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  ...  0.0180  0.0244  0.0316  0.0164  0.0095  0.0078   R
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  ...  0.0085  0.0073  0.0050  0.0044  0.0040  0.0117   R
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  ...  0.0110  0.0015  0.0072  0.0048  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
# M for Mine / R for Rock 
df[60].value_counts()
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       208 non-null    float64
#  1   1       208 non-null    float64
#  2   2       208 non-null    float64
#  3   3       208 non-null    float64
#  4   4       208 non-null    float64
#  5   5       208 non-null    float64
#  6   6       208 non-null    float64
#  7   7       208 non-null    float64
#  8   8       208 non-null    float64
#  9   9       208 non-null    float64
#  10  10      208 non-null    float64
#  11  11      208 non-null    float64
#  12  12      208 non-null    float64
#  13  13      208 non-null    float64
#  14  14      208 non-null    float64
#  15  15      208 non-null    float64
#  16  16      208 non-null    float64
#  17  17      208 non-null    float64
#  18  18      208 non-null    float64
#  19  19      208 non-null    float64
# ...

# %%
df.describe()
# Out:
#                0           1           2           3   ...          56          57          58          59
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892  ...    0.007820    0.007949    0.007941    0.006507
# std      0.022991    0.032960    0.038428    0.046528  ...    0.005785    0.006470    0.006181    0.005031
# min      0.001500    0.000600    0.001500    0.005800  ...    0.000300    0.000300    0.000100    0.000600
# 25%      0.013350    0.016450    0.018950    0.024375  ...    0.003700    0.003600    0.003675    0.003100
# 50%      0.022800    0.030800    0.034300    0.044050  ...    0.005950    0.005800    0.006400    0.005300
# 75%      0.035550    0.047950    0.057950    0.064500  ...    0.010425    0.010350    0.010325    0.008525
# max      0.137100    0.233900    0.305900    0.426400  ...    0.035500    0.044000    0.036400    0.043900
#
# ...

# %%
df.shape
# Out:
# (208, 61)

# %%
encoder = LabelEncoder()

# %%
df[60] = encoder.fit_transform(df[60])
df.head()
# Out:
#        0       1       2       3       4       5       6   ...      54      55      56      57      58      59  60
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  ...  0.0072  0.0167  0.0180  0.0084  0.0090  0.0032   1
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  ...  0.0094  0.0191  0.0140  0.0049  0.0052  0.0044   1
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  ...  0.0180  0.0244  0.0316  0.0164  0.0095  0.0078   1
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  ...  0.0085  0.0073  0.0050  0.0044  0.0040  0.0117   1
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  ...  0.0110  0.0015  0.0072  0.0048  0.0107  0.0094   1
#
# [5 rows x 61 columns]

# %% [markdown]
# #### 광물의 종류
# - 1 : R (rock)
# - 2 : M (mine)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       208 non-null    float64
#  1   1       208 non-null    float64
#  2   2       208 non-null    float64
#  3   3       208 non-null    float64
#  4   4       208 non-null    float64
#  5   5       208 non-null    float64
#  6   6       208 non-null    float64
#  7   7       208 non-null    float64
#  8   8       208 non-null    float64
#  9   9       208 non-null    float64
#  10  10      208 non-null    float64
#  11  11      208 non-null    float64
#  12  12      208 non-null    float64
#  13  13      208 non-null    float64
#  14  14      208 non-null    float64
#  15  15      208 non-null    float64
#  16  16      208 non-null    float64
#  17  17      208 non-null    float64
#  18  18      208 non-null    float64
#  19  19      208 non-null    float64
# ...

# %%
df.describe()
# Out:
#                0           1           2           3   ...          57          58          59          60
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892  ...    0.007949    0.007941    0.006507    0.466346
# std      0.022991    0.032960    0.038428    0.046528  ...    0.006470    0.006181    0.005031    0.500070
# min      0.001500    0.000600    0.001500    0.005800  ...    0.000300    0.000100    0.000600    0.000000
# 25%      0.013350    0.016450    0.018950    0.024375  ...    0.003600    0.003675    0.003100    0.000000
# 50%      0.022800    0.030800    0.034300    0.044050  ...    0.005800    0.006400    0.005300    0.000000
# 75%      0.035550    0.047950    0.057950    0.064500  ...    0.010350    0.010325    0.008525    1.000000
# max      0.137100    0.233900    0.305900    0.426400  ...    0.044000    0.036400    0.043900    1.000000
#
# ...

# %%
df[60].value_counts()
# Out:
# 60
# 0    111
# 1     97
# Name: count, dtype: int64

# %%
df_corr = df.corr()
df_corr
# Out:
#           0         1         2         3         4   ...        56        57        58        59        60
# 0   1.000000  0.735896  0.571537  0.491438  0.344797  ...  0.313725  0.368132  0.357116  0.347078 -0.271694
# 1   0.735896  1.000000  0.779916  0.606684  0.419669  ...  0.280341  0.353042  0.352200  0.358761 -0.231238
# 2   0.571537  0.779916  1.000000  0.781786  0.546141  ...  0.380819  0.334108  0.425047  0.373948 -0.192195
# 3   0.491438  0.606684  0.781786  1.000000  0.726943  ...  0.340254  0.344865  0.420266  0.400626 -0.250638
# 4   0.344797  0.419669  0.546141  0.726943  1.000000  ...  0.219395  0.238793  0.290982  0.253710 -0.222232
# ..       ...       ...       ...       ...       ...  ...       ...       ...       ...       ...       ...
# 56  0.313725  0.280341  0.380819  0.340254  0.219395  ...  1.000000  0.509805  0.431295  0.287219 -0.000933
# 57  0.368132  0.353042  0.334108  0.344865  0.238793  ...  0.509805  1.000000  0.550235  0.329827 -0.184191
# ...

# %%
df_corr.hist(sharex = False, sharey = False, xlabelsize = 1, ylabelsize = 1, figsize = (12, 12))
plt.show()

# %%
# 음파 관련 속성을 x로, 광물의 종류를 y로 저장
x = df.iloc[:, 0:60]
y = df.iloc[:, 60]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 1)

# %% [markdown]
# ## 모델 구성

# %%
model = Sequential()

# %%
# 입력층과 닿아있는 층 생성
model.add(keras.layers.Dense(24, activation = 'relu', input_shape = (60, )))

model.add(keras.layers.Dense(10, activation = 'relu')) 

# binary crossentropy를 하면 출력층에 1만 들어가야 한다.
model.add(keras.layers.Dense(1, activation = 'sigmoid'))

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'adam',
              metrics = ['accuracy'])

# %%
history = model.fit(x, y, epochs = 50, batch_size = 10)
# Out:
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5006 - loss: 0.7141
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - accuracy: 0.6228 - loss: 0.6865
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5814 - loss: 0.6851
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - accuracy: 0.5890 - loss: 0.6826
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.5889 - loss: 0.6810
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6274 - loss: 0.6641
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5697 - loss: 0.6637
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.6590 - loss: 0.6520
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7147 - loss: 0.6247
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6980 - loss: 0.6174
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.7356 - loss: 0.5811
# Epoch 12/50
# ...

# %%
plt.figure()

plt.plot(history.history['accuracy'])

plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %%
model = model_fn()
model.compile(loss = 'binary_crossentropy', metrics = ['accuracy'])
history = model.fit(x_train, y_train, epochs = 20)
# Out:
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4840 - loss: 0.6956
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.7691 - loss: 0.6693
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7397 - loss: 0.6605
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7906 - loss: 0.6558
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7665 - loss: 0.6507
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7967 - loss: 0.6470
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7318 - loss: 0.6472
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7245 - loss: 0.6411
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8032 - loss: 0.6300
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7586 - loss: 0.6214
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7200 - loss: 0.6248
# Epoch 12/20
# ...

# %%
plt.figure()

plt.plot(history.history['loss'], label = 'loss')
plt.plot(history.history['accuracy'], label = 'acc')

plt.legend()
plt.xlabel('epoch')
plt.show()

# %%
model = model_fn()
model.compile(loss = 'binary_crossentropy', metrics = ['accuracy'])
history = model.fit(x_train, y_train, epochs = 20, validation_data = (scaled_val, y_val))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[171], line 3
#       1 model = model_fn()
#       2 model.compile(loss = 'binary_crossentropy', metrics = ['accuracy'])
# ----> 3 history = model.fit(x_train, y_train, epochs = 20, validation_data = (scaled_val, y_val))
#
# NameError: name 'scaled_val' is not defined

# %% [markdown]
# - 과적합으로 나옴

# %%
x_train, x_test,y_train, y_test = train_test_split(x, y, test_size = 0.3, shuffle = True)

# %%
x_sub, x_val, y_sub, y_val = train_test_split(x_train, y_train, stratify = y_train,
                                              test_size = 0.2, random_state = 12)

# %%
# batch_size 한줄 꺼내서 가중치 돌리고 한줄 꺼내서 가중치 돌리고 : 확률 경사법 
# 딥러닝은 기본적으로 미니 배치사이즈를 쓺 
# 배치사이즈 기본값 32
model.fit(x_sub, y_sub, epochs = 50, validation_data = (x_val, y_val), batch_size = 4)

# %%
score = model.evaluate(x_test,y_test)
print('정확도 :', score[1] )
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9894 - loss: 0.1002
# 정확도 : 0.9841269850730896

# %%
model.save('./data/model/my_model.keras')

# %%
del model

# %%
model = load_model('./data/model/my_model.keras')

# %%
score = model.evaluate(x_test, y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9894 - loss: 0.1002

# %%
print('정확도 :', score[1] )
# Out:
# 정확도 : 0.9841269850730896

# %% [markdown]
# ### K겹 교차 검증

# %%
k = 5
kfold = KFold(n_splits = k, shuffle = True)
acc_score = []

# %%
for train_index, test_index in kfold.split(x):
    x_train,x_test = x.iloc[train_index, :], x.iloc[test_index, :]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# %%
new_df = pd.read_csv('./data/sonar.csv', header = None)

# %%
new_df.head()
# Out:
#        0       1       2       3       4       5       6   ...      54      55      56      57      58      59  60
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  ...  0.0072  0.0167  0.0180  0.0084  0.0090  0.0032   R
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  ...  0.0094  0.0191  0.0140  0.0049  0.0052  0.0044   R
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  ...  0.0180  0.0244  0.0316  0.0164  0.0095  0.0078   R
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  ...  0.0085  0.0073  0.0050  0.0044  0.0040  0.0117   R
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  ...  0.0110  0.0015  0.0072  0.0048  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
x = new_df.iloc[:, 0 : 60]
y = new_df.iloc[:, 60]

# %%
k= 5
kfold = KFold(n_splits = k, shuffle = True)
acc_score = []

# %%
def model_fn():
    model = Sequential()
    model.add(keras.layers.Dense(24, activation = 'relu', input_shape = (60, )))
    model.add(keras.layers.Dense(10, activation = 'relu'))
    model.add(keras.layers.Dense(1, activation = 'sigmoid'))
    return model

# %%
encoder = LabelEncoder()
df[60] = encoder.fit_transform(df[60])
df.head()
# Out:
#        0       1       2       3       4       5       6   ...      54      55      56      57      58      59  60
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  ...  0.0072  0.0167  0.0180  0.0084  0.0090  0.0032   1
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  ...  0.0094  0.0191  0.0140  0.0049  0.0052  0.0044   1
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  ...  0.0180  0.0244  0.0316  0.0164  0.0095  0.0078   1
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  ...  0.0085  0.0073  0.0050  0.0044  0.0040  0.0117   1
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  ...  0.0110  0.0015  0.0072  0.0048  0.0107  0.0094   1
#
# [5 rows x 61 columns]

# %%
for train_index, test_index in kfold.split(x):
    x_train,x_test = x.iloc[train_index, :], x.iloc[test_index, :]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    model = model_fn()
    model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    history = model.fit(x_train, y_train, epochs = 200, batch_size = 10)
    
    accuracy= model.evaluate(x_test, y_test)[1] #정확도 구하기
    acc.score.append(accuracy)
# Out:
# Epoch 1/200
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# Cell In[144], line 7
#       5 model = model_fn()
#       6 model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
# ----> 7 history = model.fit(x_train, y_train, epochs = 200, batch_size = 10)
#       9 accuracy= model.evaluate(x_test, y_test)[1] #정확도 구하기
#      10 acc.score.append(accuracy)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ...
